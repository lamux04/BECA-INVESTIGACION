# %%
nombre_train = "CIC17__RUS_SMOTE__v1__train.csv"
nombre_test = "CIC17__RUS_SMOTE__v1__test.csv"
nombre_test_nuevo = "CIC17__RUS_SMOTE__v1__test_nuevo.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC17__RUS_SMOTE__v1"
nombre_train_generado = "CIC17__RUS_SMOTE_ENN__v1__train.csv"
nombre_test_generado = "CIC17__RUS_SMOTE_ENN__v1__test.csv"
nombre_test_nuevo_generado = "CIC17__RUS_SMOTE_ENN__v1__test_nuevo.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC17__RUS_SMOTE_ENN__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)
df_test_nuevo = cargar_dataset(nombre_test_nuevo, ruta_base_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_train = cargar_dataset(nombre_train, ruta_base_dataset)
#
# NameError: name 'cargar_dataset' is not defined

# %%
df_train["LABEL"].value_counts()

# %%
df_train = aplicar_enn(df_train)

# %%
df_train["LABEL"].value_counts()

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test_nuevo, nombre_test_nuevo_generado, ruta_base_dataset_generado)
