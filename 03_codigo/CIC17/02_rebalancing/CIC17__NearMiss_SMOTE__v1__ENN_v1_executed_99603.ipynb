# %%
nombre_train = "CIC17__NearMiss_SMOTE__v1__train.csv"
nombre_test = "CIC17__NearMiss_SMOTE__v1__test.csv"
nombre_test_nuevo = "CIC17__NearMiss_SMOTE__v1__test_nuevo.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC17__NearMiss_SMOTE__v1"
nombre_train_generado = "CIC17__NearMiss_SMOTE_ENN__v1__train.csv"
nombre_test_generado = "CIC17__NearMiss_SMOTE_ENN__v1__test.csv"
nombre_test_nuevo_generado = "CIC17__NearMiss_SMOTE_ENN__v1__test_nuevo.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC17__NearMiss_SMOTE_ENN__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)
df_test_nuevo = cargar_dataset(nombre_test_nuevo, ruta_base_dataset)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     10000
# 1     10000
# 2     10000
# 3     10000
# 4     10000
# 5     10000
# 6     10000
# 7     10000
# 8     10000
# 9     10000
# 10    10000
# 11    10000
# 12    10000
# 13    10000
# 14    10000
# Name: count, dtype: int64

# %%
df_train = aplicar_enn(df_train)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     10000
# 14    10000
# 2      9995
# 9      9979
# 1      9968
# 3      9960
# 4      9958
# 12     9934
# 5      9923
# 7      9872
# 6      9785
# 13     9727
# 8      9637
# 11     5871
# 10     5793
# Name: count, dtype: int64

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test_nuevo, nombre_test_nuevo_generado, ruta_base_dataset_generado)
