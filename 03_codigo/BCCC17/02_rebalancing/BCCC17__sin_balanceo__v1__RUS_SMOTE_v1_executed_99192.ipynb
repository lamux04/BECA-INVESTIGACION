# %%
nombre_train = "BCCC17__sin_balanceo__v1__train.csv"
nombre_test = "BCCC17__sin_balanceo__v1__test.csv"
ruta_base_dataset = "../../../02_datasets/processed/BCCC17__sin_balanceo__v1"
nombre_train_generado = "BCCC17__RUS_SMOTE__v1__train.csv"
nombre_test_generado = "BCCC17__RUS_SMOTE__v1__test.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/BCCC17__RUS_SMOTE__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     1428029
# 1      276961
# 2      129058
# 3       76583
# 4        7625
# 5        6691
# 6        5485
# 7        4759
# 8        4406
# 9        4098
# 10       2187
# 11       1086
# 12         19
# 13         10
# Name: count, dtype: int64

# %%
df_train, df_test_nuevo = balancear_y_mover_a_test(df_train, df_test, "LABEL", 10000)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 2     10000
# 0     10000
# 6     10000
# 1     10000
# 5     10000
# 7     10000
# 8     10000
# 3     10000
# 10    10000
# 11    10000
# 4     10000
# 9     10000
# 12    10000
# 13    10000
# Name: count, dtype: int64

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test_nuevo, nombre_test_generado.replace(".csv", "_nuevo.csv"), ruta_base_dataset_generado)
