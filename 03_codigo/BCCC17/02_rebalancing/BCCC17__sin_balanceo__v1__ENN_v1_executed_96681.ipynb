# %%
nombre_train = "BCCC17__sin_balanceo__v1__train.csv"
nombre_test = "BCCC17__sin_balanceo__v1__test.csv"
ruta_base_dataset = "../../../02_datasets/processed/BCCC17__sin_balanceo__v1"
nombre_train_generado = "BCCC17__ENN__v1__train.csv"
nombre_test_generado = "BCCC17__ENN__v1__test.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/BCCC17__ENN__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     1428029
# 1      276961
# 2      129058
# 3       76583
# 4        7625
# 5        6691
# 6        5485
# 7        4759
# 8        4406
# 9        4098
# 10       2187
# 11       1086
# 12         19
# 13         10
# Name: count, dtype: int64

# %%
df_train = aplicar_enn(df_train)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     1427700
# 1      275565
# 2      129044
# 3       75502
# 4        7608
# 5        6423
# 6        5325
# 7        4732
# 8        4393
# 9        3980
# 10       2176
# 11       1076
# 13         10
# 12          5
# Name: count, dtype: int64

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
