# %%
nombre_dataset = "BCCC17__cleanning__v1.csv"
ruta_base_dataset = "../../../02_datasets/processed/BCCC17__cleanning__v1"
nombre_dataset_generado = "BCCC17__cleanning_division__v1.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/BCCC17__cleanning_division__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df = cargar_dataset(nombre_dataset, ruta_base_dataset)

# %%
train_df, test_df = dividir_train_test_stratified(df, "LABEL", 0.2)

# %%
nombre_train = nombre_dataset_generado.replace(".csv", "__train.csv")
nombre_test = nombre_dataset_generado.replace(".csv", "__test.csv")

# %%
guardar_dataset_csv(train_df, nombre_train, ruta_base_dataset_generado)
guardar_dataset_csv(test_df, nombre_test, ruta_base_dataset_generado)
