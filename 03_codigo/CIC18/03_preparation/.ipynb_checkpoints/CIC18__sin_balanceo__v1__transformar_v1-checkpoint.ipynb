# %%
nombre_dataset = "CIC18__cleanning_RUS__v1.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC18__cleanning_RUS__v1"
nombre_dataset_generado = "CIC18__sin_balanceo__v1.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC18__sin_balanceo__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df = cargar_dataset(nombre_dataset, ruta_base_dataset)

# %%
particiones = dividir_en_k_particiones_stratified(df, "LABEL", 5)

# %%
k = 1
for df_part in particiones:
    df_string = dataframe_a_columna_string(df_part)
    guardar_dataset_csv(df_string, nombre_dataset_generado.replace(".csv", f"__{k}_5.csv"), ruta_base_dataset_generado)
    k += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 k = 1
#       2 for df_part in particiones:
# ----> 3     df_string = dataframe_a_columna_string(df_part)
#       4     guardar_dataset_csv(df_string, nombre_dataset_generado.replace(".csv", f"__{k}_5.csv"), ruta_base_dataset_generado)
#       5     k += 1
#
# File ~/Documentos/TFG/03_codigo/CIC17/03_preparation/../../utils/utils.py:191, in dataframe_a_columna_string(df, sep, nombre_col)
#     189 def dataframe_a_columna_string(df, sep="|", nombre_col="text"):
# --> 191     df_texto = df.astype(str).agg(sep.join, axis=1)
#     193     return df_texto.to_frame(name=nombre_col)
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/frame.py:12030, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   12027 axis = self._get_axis_number(axis)
#   12029 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 12030 result = op.agg()
#   12031 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   12032 return result
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/apply.py:1022, in FrameApply.agg(self)
#    1019 axis = self.axis
#    1021 # TODO: Avoid having to change state
# -> 1022 self.obj = self.obj if self.axis == 0 else self.obj.T
#    1023 self.axis = 0
#    1025 result = None
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/frame.py:4287, in DataFrame.T(self)
#    4260 @property
#    4261 def T(self) -> DataFrame:
#    4262     """
#    4263     The transpose of the DataFrame.
#    4264
#    (...)   4285     col2  3  4
#    4286     """
# -> 4287     return self.transpose()
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/frame.py:4236, in DataFrame.transpose(self, copy, *args)
#    4234         arr_typ = first_dtype.construct_array_type()
#    4235         values = self.values
# -> 4236         new_values = [
#    4237             arr_typ._from_sequence(row, dtype=first_dtype) for row in values
#    4238         ]
#    4240     result = type(self)._from_arrays(
#    4241         new_values,
#    4242         index=self.columns,
#    4243         columns=self.index,
#    4244         verify_integrity=False,
#    4245     )
#    4247 else:
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/frame.py:4237, in <listcomp>(.0)
#    4234         arr_typ = first_dtype.construct_array_type()
#    4235         values = self.values
#    4236         new_values = [
# -> 4237             arr_typ._from_sequence(row, dtype=first_dtype) for row in values
#    4238         ]
#    4240     result = type(self)._from_arrays(
#    4241         new_values,
#    4242         index=self.columns,
#    4243         columns=self.index,
#    4244         verify_integrity=False,
#    4245     )
#    4247 else:
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/arrays/string_arrow.py:200, in ArrowStringArray._from_sequence(cls, scalars, dtype, copy)
#     194 @classmethod
#     195 def _from_sequence(
#     196     cls, scalars, *, dtype: Dtype | None = None, copy: bool = False
#     197 ) -> Self:
#     198     from pandas.core.arrays.masked import BaseMaskedArray
# --> 200     _check_pyarrow_available()
#     202     if dtype and not (isinstance(dtype, str) and dtype == "string"):
#     203         dtype = pandas_dtype(dtype)
#
# File ~/miniforge3/envs/tfg/lib/python3.11/site-packages/pandas/core/arrays/string_arrow.py:66, in _check_pyarrow_available()
#      61     from pandas.core.dtypes.dtypes import ExtensionDtype
#      63     from pandas import Series
# ---> 66 def _check_pyarrow_available() -> None:
#      67     if not HAS_PYARROW:
#      68         msg = (
#      69             f"pyarrow>={PYARROW_MIN_VERSION} is required for PyArrow "
#      70             "backed ArrowExtensionArray."
#      71         )
#
# KeyboardInterrupt:
