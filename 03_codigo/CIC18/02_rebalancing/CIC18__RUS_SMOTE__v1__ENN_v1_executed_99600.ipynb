# %%
nombre_train = "CIC18__RUS_SMOTE__v1__train.csv"
nombre_test = "CIC18__RUS_SMOTE__v1__test.csv"
nombre_test_nuevo = "CIC18__RUS_SMOTE__v1__test_nuevo.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC18__RUS_SMOTE__v1"
nombre_train_generado = "CIC18__RUS_SMOTE_ENN__v1__train.csv"
nombre_test_generado = "CIC18__RUS_SMOTE_ENN__v1__test.csv"
nombre_test_nuevo_generado = "CIC18__RUS_SMOTE_ENN__v1__test_nuevo.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC18__RUS_SMOTE_ENN__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)
df_test_nuevo = cargar_dataset(nombre_test_nuevo, ruta_base_dataset)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 5     10000
# 3     10000
# 8     10000
# 7     10000
# 9     10000
# 4     10000
# 12    10000
# 2     10000
# 0     10000
# 1     10000
# 10    10000
# 11    10000
# 6     10000
# 13    10000
# 14    10000
# Name: count, dtype: int64

# %%
df_train = aplicar_enn(df_train)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     10000
# 9     10000
# 11    10000
# 14     9987
# 8      9986
# 2      9974
# 4      9971
# 6      9896
# 3      9855
# 1      9840
# 10     9838
# 13     9673
# 12     9624
# 7      9533
# 5      8820
# Name: count, dtype: int64

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test_nuevo, nombre_test_nuevo_generado, ruta_base_dataset_generado)
