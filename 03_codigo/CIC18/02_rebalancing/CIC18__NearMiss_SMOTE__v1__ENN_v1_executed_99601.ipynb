# %%
nombre_train = "CIC18__NearMiss_SMOTE__v1__train.csv"
nombre_test = "CIC18__NearMiss_SMOTE__v1__test.csv"
nombre_test_nuevo = "CIC18__NearMiss_SMOTE__v1__test_nuevo.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC18__NearMiss_SMOTE__v1"
nombre_train_generado = "CIC18__NearMiss_SMOTE_ENN__v1__train.csv"
nombre_test_generado = "CIC18__NearMiss_SMOTE_ENN__v1__test.csv"
nombre_test_nuevo_generado = "CIC18__NearMiss_SMOTE_ENN__v1__test_nuevo.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC18__NearMiss_SMOTE_ENN__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)
df_test_nuevo = cargar_dataset(nombre_test_nuevo, ruta_base_dataset)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     10000
# 1     10000
# 2     10000
# 3     10000
# 4     10000
# 5     10000
# 6     10000
# 7     10000
# 8     10000
# 9     10000
# 10    10000
# 11    10000
# 12    10000
# 13    10000
# 14    10000
# Name: count, dtype: int64

# %%
df_train = aplicar_enn(df_train)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 0     10000
# 4     10000
# 8     10000
# 9     10000
# 11    10000
# 5      9998
# 1      9993
# 14     9986
# 7      9974
# 2      9968
# 6      9967
# 10     9939
# 3      9914
# 13     9655
# 12     9593
# Name: count, dtype: int64

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test_nuevo, nombre_test_nuevo_generado, ruta_base_dataset_generado)
