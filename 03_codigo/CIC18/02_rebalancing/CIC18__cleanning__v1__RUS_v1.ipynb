# %%
nombre_dataset = "CIC18__cleanning__v1.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC18__cleanning__v1"
nombre_dataset_generado = "CIC18__cleanning_RUS__v1.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC18__cleanning_RUS__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df = cargar_dataset(nombre_dataset, ruta_base_dataset)

# %%
df = undersample_clase_mayoritaria_rus(df, (df["LABEL"] != 0).sum(), "LABEL")

# %%
df["LABEL"].value_counts()

# %%
guardar_dataset_csv(df, nombre_dataset_generado, ruta_base_dataset_generado)
