# %%
nombre_train = "CIC18__sin_balanceo__v1__train.csv"
nombre_test = "CIC18__sin_balanceo__v1__test.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC18__sin_balanceo__v1"
nombre_train_generado = "CIC18__ENN__v1__train.csv"
nombre_test_generado = "CIC18__ENN__v1__test.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC18__ENN__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df_train = cargar_dataset(nombre_train, ruta_base_dataset)
df_test = cargar_dataset(nombre_test, ruta_base_dataset)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 2     360000
# 0     360000
# 1     360000
# 3     347898
# 4     225848
# 5     129517
# 6      93857
# 7      33164
# 8      31482
# 9      15570
# 10      8228
# 11      1384
# 12       489
# 13       184
# 14        70
# Name: count, dtype: int64

# %%
df_train = aplicar_enn(df_train)

# %%
df_train["LABEL"].value_counts()
# Out:
# LABEL
# 2     359369
# 1     359280
# 3     346118
# 0     339865
# 4     225602
# 5     108526
# 6      93112
# 8      31432
# 7      31187
# 9      15570
# 10      7975
# 11      1378
# 12       211
# 14        70
# 13        66
# Name: count, dtype: int64

# %%
guardar_dataset_csv(df_train, nombre_train_generado, ruta_base_dataset_generado)
guardar_dataset_csv(df_test, nombre_test_generado, ruta_base_dataset_generado)
