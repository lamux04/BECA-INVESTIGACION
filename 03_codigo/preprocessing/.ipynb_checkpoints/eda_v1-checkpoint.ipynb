# %%
import pandas as pd
import glob
import os

directorio_actual = os.getcwd()
nombre_dataset = "/CIC17"
directorio_dataset = directorio_actual + "/../../02-datasets/raw" + nombre_dataset
archivos = glob.glob(directorio_dataset + "/*.csv")

df_list = []

for archivo in archivos:
    df_temp = pd.read_csv(archivo)
    df_list.append(df_temp)

#df = pd.concat(df_list, ignore_index=True)

# %%
archivos
# Out:
# []

# %%
import os
os.listdir(directorio_dataset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 os.listdir(directorio_dataset)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ana/Documentos/TFG/03_codigo/preprocessing/../../02-datasets/raw/CIC17'

# %%
import os
print(os.listdir("/home/ana/Documentos/TFG"))
print(os.listdir("/home/ana/Documentos/TFG/02-datasets"))
print(os.listdir("/home/ana/Documentos/TFG/02-datasets/raw"))
# Out:
# ['02_datasets', '05_memoria', '.ipynb_checkpoints', '03_codigo', '01_documentacion', '.git', '04_experimentos']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
#       2 print(os.listdir("/home/ana/Documentos/TFG"))
# ----> 3 print(os.listdir("/home/ana/Documentos/TFG/02-datasets"))
#       4 print(os.listdir("/home/ana/Documentos/TFG/02-datasets/raw"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ana/Documentos/TFG/02-datasets'
