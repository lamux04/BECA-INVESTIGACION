# %%
nombre_dataset = "CIC18__cleanning_division__v1__train.csv"
ruta_base_dataset = "../../../02_datasets/processed/CIC18__cleanning_division__v1"
nombre_dataset_generado = "CIC18__cleanning_division__v1__train.csv"
ruta_base_dataset_generado = "../../../02_datasets/processed/CIC18__cleanning_division__v1"

# %%
import sys
sys.path.append("../../utils/")

from utils import *

# %%
df = cargar_dataset(nombre_dataset, ruta_base_dataset)

# %%
particiones = dividir_en_k_particiones_stratified(df, "LABEL", 5)

# %%
k = 1
for df_part in particiones:
    df_string = dataframe_a_columna_string(df_part)
    guardar_dataset_csv(df_string, nombre_dataset_generado.replace(".csv", f"__{k}_5.csv"), ruta_base_dataset_generado)
    k += 1
